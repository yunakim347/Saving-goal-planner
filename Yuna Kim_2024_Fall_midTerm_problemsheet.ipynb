# %% [markdown]
# <a href="https://colab.research.google.com/github/yunakim347/Saving-goal-planner/blob/main/Yuna%20Kim_2024_Fall_midTerm_problemsheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 시험 안내
# - 시험 시간 : 2시간
#   - 시험 시간 1시간 30분이후 퇴실 가능
#
# - 파일 제출시 이름.ipynb으로 제출해주시기바랍니다
# - .ipynb 제출 방법은 [파일]-[다운로드]-[.ipynb 다운로드]후 이메일로 제출해주세요.
# - 이메일 : unicentrekor.dean@gmail.com

# %% [markdown]
# 문제 배점
# - 문제. 1 : 5점
# - 문제. 2 : 10점
# - 문제. 3 : 10점
# - 문제. 4 : 5점
# - 문제. 5 : 10점
# - 문제. 6 : 10점
# - 문제. 7 : 10점
# - 문제. 8 : 5점
# - 문제. 9 : 10점
# - 문제. 10 : 15점
# - 문제. 11 : 10점

# %% [markdown]
# ## 문제 1.
# - 사용자로부터 두 개의 정수를 받아서 다음을 출력하는 프로그램을 작성하라.
#   - 1. 정수의 합,
#   - 2. 정수의 차,
#   - 3. 정수의 곱,
#   - 4. 정수의 평균,
#   - 5. 큰 수, 작은 수
# - 파이썬이 제공하는 내장 함수 sum(), max(), min()을 사용 가능
# - 두수의 차는 첫번째 정수 - 두번째 정수입니다
#
# - 출력 예시
#   - (입력)10
#   - (입력)20
#   - 두수의 합: 30
#   - 두수의 차: -10
#   - 두수의 곱: 200
#   - 두수의 평균: 15.0
#   - 큰수: 20 , 작은수: 10

# %%
a=int(input("(입력)"))
b=int(input("(입력)"))
print(f"두수의 합: {a+b}")
print(f"두수의 차: {a-b}")
print(f"두수의 곱: {a*b}")
print(f"두수의 평균: {(a+b)/2:.1f}")
print(f"큰수: {max(a, b)}, 작은수: {min(a, b)}")
# Out:
# (입력)10
# (입력)20
# 두수의 합: 30
# 두수의 차: -10
# 두수의 곱: 200
# 두수의 평균: 15.0
# 큰수: 20, 작은수: 10

# %% [markdown]
# ## 문제 2.
# - 자동 판매기를 시뮬레이션하는 프로그램을 작성해보자.
# - 사용자로부터 삽입한 돈과 물건값을 입력받는다.
# - 자동 판매기는 1000원권만 받을 수 있고, 물건값은 100원 단위이다.
# - 잔돈은 동전으로만 계산 가능하다.
# - 잔돈의 동전은 500원, 100원짜리만 있다고 하자.
# - 입력 예시
#   - 1000원권 개수: 5
#   - 물건값: 2600
# - 출력 예시
#   - 500원 동전의 개수: 4
#   - 100원 동전의 개수: 4

# %%
a=int(input("100원권 개수:"))
b=int(input("물건값:"))
c= (a*1000)-b
d= c//500
e= (c-(d*500))//100
print(f"500원 동전의 개수:{d}")
print(f"100원 동전의 개수:{e}")
# Out:
# 100원권 개수:5
# 물건값:2600
# 500원 동전의 개수:4
# 100원 동전의 개수:4

# %% [markdown]
# ## 문제 3. 중복된 숫자 체크
# - 사용자에게 5개의 숫자를 입력받아 입력한 숫자들에 중복된 숫자가 있는 지 없는 지 판단해주는 프로그램을 작성하시오
#
#
# - 입력 예)
#     - 10 7 22 5 10
# - 출력 예)
#     - 중복된 숫자가 있습니다
# - 입력 예)
#     - 11 9 27 34 42
# - 출력 예)
#     - 중복된 숫자가 없습니다

# %%
a=list(map(int, input().split()))
aa=set(a)
b=list(aa)
if len(b)==len(a):
  print("중복된 숫자가 없습니다.")
else:
  print("중복된 숫자가 있습니다.")
# Out:
# 6 3 9 7 8
# 중복된 숫자가 없습니다.

# %% [markdown]
# ## 문제 4.
# - BMI(Body Mass Index)는 체중(kg)을 신장(m)의 제곱으로 나눈 값으로 체지방 축적을 잘 반영하기 때문에 비만도 판정에 많이 사용한다.
# - 사용자로부터 신장과 체중을 입력받아서 BMI 값에 따라서 다음과 같은 메시지를 출력하는 프로그램을 작성하여 보자.
# - BMI 판정 기준
#   - 18.5미만 : "저체중"
#   - 18.5 ~ 22.9 : "정상"
#   - 23 ~ 24.9 : "비만 전 단계"
#   - 25 ~ 29.9 : "1단계 비만"
#   - 30 ~ 34.9 : "2단계 비만"
#   - 35이상 : "3단계 비만"
#
#
# - 예시
#   - 신장(m): 1.76(입력)
#   - 체중: 61.6(입력)
# - 출력 예시
#   - 정상

# %%
a=float(input("신장(m):"))
b=float(input("체중:"))
bmi=b/(a**2)
if bmi>=35:
  print("3단계 비만")
elif bmi>=30:
  print("2단계 비만")
elif bmi>=25:
  print("1단계 비만")
elif bmi>=23:
  print("비만 전 단계")
elif bmi>=18.5:
  print("정상")
elif bmi<18.5:
  print("저체중")
# Out:
# 신장(m):1.76
# 체중:50
# 저체중

# %% [markdown]
# ## 문제 5.
# - 다음의 출력 결과생성하는 프로그램을 작성하시오
# - 반드시 중첩 반복문을 활용할 것

# %%
# - 예시 1)
#     - 입력 : 3

#     - 출력 :
#   A
#  BBB
# CCCCC

# - 예시 2)
#     - 입력 : 5
#     - 출력 :
#     A
#    BBB
#   CCCCC
#  DDDDDDD
# EEEEEEEEE

# %%
n=int(input("입력 : "))
for i in range(n):
  for j in range(65, 65+n+1):
    print(f"{j*(i*2+1)}")
print()

# %% [markdown]
# ## 문제 6.
# - 소수인지 아닌지 판단하는 프로그램을 작성하시오
# - 입력되는 수는 정수 전체 범위입니다. 반드시 올바르지 않은 결과는 예외처리 하시기바랍니다
#
# - 예시)
#     - 입력 : 7
#     - 출력 : "소수입니다"
#
# - 예시2)
#     - 입력 : 21
#     - 출력 : "소수가 아닙니다"
#
# - 예시3)
#     - 입력 : -3
#     - 출력 : "음수는 소수 판별이 불가능합니다"

# %%
a=int(input())
cnt=0
if a<0:
  print("음수는 소수 판별이 불가능합니다.")
for i in range(1, a+1):
  if a%i==0:
    cnt+=1
if cnt>2:
  print("소수가 아닙니다.")
elif cnt==2:
  print("소수입니다.")
# Out:
# 21
# 소수가 아닙니다.

# %% [markdown]
# ## 문제 7.
# - 사용자로부터 5개의 숫자를 읽어서 리스트에 저장하고 숫자들의 평균을 계산하여 출력한다.
# - 또 숫자 중에서 평균보다 큰 숫자가 몇 개인지 출력하는 프로그램을 작성하시오.
# - 입력 예시
#   - 정수를 입력하세요: 10
#   - 정수를 입력하세요: 20
#   - 정수를 입력하세요: 30
#   - 정수를 입력하세요: 40
#   - 정수를 입력하세요: 50
# - 출력 예시
#   - 평균 : 30.0
#   - 평균보다 큰 숫자의 개수 : 2개

# %%
sum=0
c=[]
cnt=0
for i in range(5):
  a=int(input("정수를 입력하세요:"))
  sum+=a
  c.append(a)
for i in c:
  if i>(sum/5):
    cnt+=1
print(f"평균 : {sum/5:.1f}")
print(f"평균보다 큰 숫자의 개수: {cnt}개")
# Out:
# 정수를 입력하세요:30
# 정수를 입력하세요:40
# 정수를 입력하세요:50
# 정수를 입력하세요:60
# 정수를 입력하세요:70
# 평균 : 50.0
# 평균보다 큰 숫자의 개수: 2개

# %% [markdown]
# ## 문제 8.
# - 사용자가 입력한 문자열과 특정한 문자를 입력받아 문자열안에 포함된 문자의 빈도를 계산하는 프로그램을 작성해보자.
# - 예를 들어서 사용자에 문자열“Welcome to Python”에서 문자 “o”의 빈도를 계산하는 프로그램을 작성한다
#
# - 입력 예시
#   - 문자열을 입력하시오: Welcome to Python
#   - 찾고 싶은 문자를 입력해주세요: o
# - 출력 예시
#   - 문자열에 포함된 'o'의 개수 : 3

# %%
a=input("문자열을 입력하시오:")
b=input("찾고 싶은 문자를 입력해주세요:")
cnt=0
for i in a:
  if i==b:
    cnt+=1
print(f"문자열에 포함된 '{b}'의 개수: {cnt}")
# Out:
# 문자열을 입력하시오:Welcome to Python
# 찾고 싶은 문자를 입력해주세요:e
# 문자열에 포함된 'e'의 개수: 2

# %% [markdown]
# ## 문제 9.
# - 사용자로부터 생년월일을 입력받아 올바른 생년월일인지를 검사하는 프로그램을 작성하라.
# - 예를 들면 “19991301”과 같은 문자열은 올바른 생년월일이 아니다.
# - 13월 1일은 올바르지 않다.
# - 연도는 1900이후 출생만 허용하도록한다
#
# - 입력 예시
#   - 생년월일을을 입력하시오: 19700123
#
# - 출력 예시
#   - 올바른 생년월일입니다.

# %%
a=input("생년월일을 입력하시오: ")
if int(a[5])>2 and int(a[4])==1: #12월을 넘을 때
  print("올바른 생년월일이 아니다.")
elif int(a[0])==0 and int(a[1])==0 and int(a[2])==0 and int(a[3])==0: #년도가 00일때
  print("올바른 생년월일이 아니다.")
elif int(a[5])==0 and int(a[4])==0: #달이 00일 때
  print("올바른 생년월일이 아니다.")
elif int(a[6])==0 and int(a[7])==0: #일이 00일 때
  print("올바른 생년월일이 아니다.")
elif len(str(a))!=8: #8글자를 넘을 때
  print("올바른 생년월일이 아니다.")
elif int(a[5])==2 and int(a[6])>=3 and int(a[7])>=0: #2월이 30일을 넘을 때
  print("올바른 생년월일이 아니다.")
elif int(a[4])==0 and (int(a[5])==1 or int(a[5])==3 or int(a[5])==5 or int(a[5])==7 or int(a[5])==8) and int(a[7])>=2: #1, 3, 5, 7, 8이 31일을 넘을 때
  print("올바른 생년월일이 아니다.")
elif (int(a[5])==0 or int(a[5]==2)) and int(a[4])==1 and int(a[7])>=2: #10월 12월
  print("올바른 생년월일이 아니다.")
elif (int(a[5])==4 or int(a[5])==6 or int(a[5])==9) and int(a[4])==0 and int(7)>=1: #4, 6, 9이 30일을 넘을 때
  print("올바른 생년월일이 아니다.")
elif int(a[5])==1 and int(a[7])>=1: #11월이 30일을 넘을 때
  print("올바른 생년월일이 아니다.")
else:
  print("올바른 생년월일이다.")
# Out:
# 생년월일을 입력하시오: 19900230
# 올바른 생년월일이 아니다.

# %% [markdown]
# ## 문제 10.
# - 전화 키패드에는 각 숫자키마다 3개의 문자가 적혀있다.
# - 사용자가 입력한 문자열을 전화기의 숫자키로 암호화하는 프로그램을 작성해보자.
# - ![Screen Shot 2021-10-28 at 11.59.44 AM 1.png](data:image/png;base64,...)
#
# - 입력 예시
#   - 문자열을 입력하시오: NUMBER
# - 출력 예시:
#   - 686237

# %%
a=input("문자열을 입력하시오:")
li=[]
for i in a:
  if chr(65)<=i<chr(68):
    li.append(2)
  elif chr(68)<=i<chr(71):
    li.append(3)
  elif chr(71)<=i<chr(74):
    li.append(4)
  elif chr(74)<=i<chr(77):
    li.append(5)
  elif chr(77)<=i<chr(80):
    li.append(6)
  elif chr(80)<=i<chr(84):
    li.append(7)
  elif chr(84)<=i<chr(87):
    li.append(8)
  elif chr(87)<=i<chr(91):
    li.append(9)
for i in li:
  print(i, end="")
# Out:
# 문자열을 입력하시오:NUMBER
# 686237

# %% [markdown]
# # 문제 11.
# - "Death toll rises to 14 in Israeli raid on refugee camp in the West Bank, Palestinian health ministry says. At least 14 people have been killed during the ongoing Israel Defense Forces operation at the Nur alShams refugee camp in the occupied West Bank, according to the Palestinian Ministry of Health. Palestinian authorities say they have been able to retrieve a number of bodies and injured people from the camp, as the IDF has partially withdrawn from the area. Videos filmed by residents show a bulldozer destroying a building as IDF vehicles leave the camp after more than 24 hours of the raid. Other videos show ambulances entering the camp after the IDF withdraws. Residents tell CNN that Israeli forces have left the immediate area but are still present in the nearby city of Tulkarm. Earlier on Saturday, the IDF said its forces killed 10 'terrorists' and arrested eight wanted suspects during the extensive operation, which started on Thursday. The health ministry and Palestinian news agency Wafa, meanwhile, have said at least one child and one teen are among those killed, and that the IDF has arrested young people en masse and destroyed key infrastructure. The operation appears to be one of the largest in the West Bank since October 7."
#
# - 위의 택스트에서 숫자와 특수문자를 제외한 unique한 단어의 개수를 찾으시오.
# -
# - 예시)
#     - "My name is dean. my hobby is python programming '3' 2024.4.20."
#     - unique한 단어의 개수 : 7
#
# - 설명
#     - My, my은 같은 단어 ( 대소문자 구분 하지 않음)
#     - .이나 따움표('), 숫자 3,2024,는 제외시킨다
#     - my, name , is , dean, hobby, python, programming 총 7개의 unique한 단어가 추출된다
#
# - 정답의 개수만 맞추면 부분점수입니다(5점)

# %%
a=list(input().split())
cnt=0
for i in a:
  a[i].lower()
  if a[i]==a[i-1]:
    continue
  elif '.' in i:
    continue
  elif '\'' in i:
    continue
  elif type(i)==int:
    continue
  else:
    cnt+=1
print(f"unique한 단어의 개수: {cnt}")
# Out:
# My name is dean. my hobby is python programming '3' 2024.4.20.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-1aadb16fa8c9> in <cell line: 3>()
#       2 cnt=0
#       3 for i in a:
# ----> 4   b=a[i].lower()
#       5   if b==a[i]:
#       6     continue
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# # 건의사항
